# %%
# %matplotlib inline
import nba_py as nba
from nba_py import player
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nba.constants.CURRENT_SEASON
# Out:
# '2016-17'

# %%
player.PlayerCareer('1938', per_mode = 'PerGame').all_star_season_totals()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0       1938   2004-05        00  1610616834               WST        27.0
# 1       1938   2010-11        00  1610616834               WST        33.0
#
#    GP  GS   MIN  FGM ...   FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0   1   0  22.0  3.0 ...     1.00   2.0   1.0  3.0  1.0  1.0  1.0  3.0  3.0
# 1   1   0  20.7  2.0 ...     0.75   1.0   2.0  3.0  5.0  3.0  0.0  2.0  3.0
#
#    PTS
# 0  8.0
# 1  7.0
#
# [2 rows x 27 columns]

# %%
nba.constants.Outcome.Loss
# Out:
# 'L'

# %%
from nba_py import game 

boxscore_summary = game.BoxscoreSummary("0021600457")
print(boxscore_summary.game_summary())
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2016-12-25T00:00:00              2  0021600457               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20161225/GSWCLE    1610612739       1610612744   2016
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                           ABC
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0         Q4       - ABC          1

# %%
help(player)
# Out:
# Help on module nba_py.player in nba_py:
#
# NAME
#     nba_py.player
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         PlayerNotFoundException
#     builtins.object
#         PlayerCareer
#             PlayerProfile
#         PlayerGameLogs
#         PlayerList
#         PlayerSummary
#         PlayerVsPlayer
#     _PlayerDashboard(builtins.object)
#         PlayerClutchSplits
#         PlayerDefenseTracking
#         PlayerGeneralSplits
#         PlayerInGameSplits
#         PlayerLastNGamesSplits
#         PlayerOpponentSplits
#         PlayerPassTracking
#         PlayerPerformanceSplits
#         PlayerReboundLogTracking
#         PlayerReboundTracking
#         PlayerShootingSplits
#         PlayerShotLogTracking
#         PlayerShotTracking
#         PlayerYearOverYearSplits
#
#     class PlayerCareer(builtins.object)
#      |  Contains stats based on several parameters such as career regular season
# ...

# %%
player.get_player('Manu', 'Ginobili', season='2016-17', only_current=0, just_id=True)
# Out:
# 1301    1938
# Name: PERSON_ID, dtype: int64

# %%
player_shooting_splits = player.PlayerShootingSplits("1938")
print(player_shooting_splits.shot_areas())
# Out:
#    GROUP_SET            GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0  Shot Area        Restricted Area   49  100   0.490     0     0    0.000
# 1  Shot Area  In The Paint (Non-RA)   19   52   0.365     0     0    0.000
# 2  Shot Area              Mid-Range   14   60   0.233     0     0    0.000
# 3  Shot Area          Left Corner 3    8   24   0.333     8    24    0.333
# 4  Shot Area         Right Corner 3    4   15   0.267     4    15    0.267
# 5  Shot Area      Above the Break 3   77  184   0.418    77   184    0.418
# 6  Shot Area              Backcourt    0    4   0.000     0     4    0.000
#
#    EFG_PCT  BLKA          ...            EFG_PCT_RANK  BLKA_RANK  \
# 0    0.490     6          ...                       3          6
# 1    0.365     9          ...                       5          7
# 2    0.233     2          ...                       6          5
# 3    0.500     0          ...                       2          1
# ...

# %%
player_shooting_splits.shot_areas()
# Out:
#    GROUP_SET            GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0  Shot Area        Restricted Area   49  100   0.490     0     0    0.000
# 1  Shot Area  In The Paint (Non-RA)   19   52   0.365     0     0    0.000
# 2  Shot Area              Mid-Range   14   60   0.233     0     0    0.000
# 3  Shot Area          Left Corner 3    8   24   0.333     8    24    0.333
# 4  Shot Area         Right Corner 3    4   15   0.267     4    15    0.267
# 5  Shot Area      Above the Break 3   77  184   0.418    77   184    0.418
# 6  Shot Area              Backcourt    0    4   0.000     0     4    0.000
#
#    EFG_PCT  BLKA          ...            EFG_PCT_RANK  BLKA_RANK  \
# 0    0.490     6          ...                       3          6
# 1    0.365     9          ...                       5          7
# 2    0.233     2          ...                       6          5
# 3    0.500     0          ...                       2          1
# ...

# %%
from nba_py import game
boxscore_summary = game.BoxscoreSummary("0021600457")
boxscore_summary.game_summary()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2016-12-25T00:00:00              2  0021600457               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20161225/GSWCLE    1610612739       1610612744   2016
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                           ABC
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0         Q4       - ABC          1

# %%
# all current players
plist = player.PlayerList(league_id='00', season='2016-17', only_current=1)

# %%
df = plist.info()

# %%
df.head()
# Out:
#    PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0     203518            Abrines, Alex       Alex Abrines             1
# 1     203112              Acy, Quincy         Quincy Acy             1
# 2     203500            Adams, Steven       Steven Adams             1
# 3     201167           Afflalo, Arron      Arron Afflalo             1
# 4     201582           Ajinca, Alexis      Alexis Ajinca             1
#
#   FROM_YEAR TO_YEAR     PLAYERCODE     TEAM_ID      TEAM_CITY TEAM_NAME  \
# 0      2016    2016   alex_abrines  1610612760  Oklahoma City   Thunder
# 1      2012    2016     quincy_acy  1610612751       Brooklyn      Nets
# 2      2013    2016   steven_adams  1610612760  Oklahoma City   Thunder
# 3      2007    2016  arron_afflalo  1610612758     Sacramento     Kings
# 4      2008    2016  alexis_ajinca  1610612740    New Orleans  Pelicans
#
#   TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG
# 0               OKC   thunder                 Y
# ...

# %%
df[df['PERSON_ID'] == 1938]
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 155       1938           Ginobili, Manu      Manu Ginobili             1
#
#     FROM_YEAR TO_YEAR     PLAYERCODE     TEAM_ID    TEAM_CITY TEAM_NAME  \
# 155      2002    2016  manu_ginobili  1610612759  San Antonio     Spurs
#
#     TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG
# 155               SAS     spurs                 Y

# %%
main_df = df[['PERSON_ID', 'DISPLAY_FIRST_LAST']]

# %%
main_df
# Out:
#      PERSON_ID     DISPLAY_FIRST_LAST
# 0       203518           Alex Abrines
# 1       203112             Quincy Acy
# 2       203500           Steven Adams
# 3       201167          Arron Afflalo
# 4       201582          Alexis Ajinca
# 5       202332           Cole Aldrich
# 6       200746      LaMarcus Aldridge
# 7       202730            Lavoy Allen
# 8         2754             Tony Allen
# 9       202329        Al-Farouq Aminu
# 10        2365         Chris Andersen
# 11      101187          Alan Anderson
# 12     1626147        Justin Anderson
# 13      203937          Kyle Anderson
# 14      201583          Ryan Anderson
# 15      203507  Giannis Antetokounmpo
# 16        2546        Carmelo Anthony
# 17      201202           Joel Anthony
# 18        2772           Trevor Ariza
# 19      201589         Darrell Arthur
# 20      201600              Omer Asik
# 21      201571          D.J. Augustin
# 22      202337           Luke Babbitt
# 23     1627758              Ron Baker
# ...

# %%
player.PlayerInGameSplits('2546').by_period()
# Out:
#    GROUP_SET  GROUP_VALUE  GP   W   L  W_PCT   MIN  FGM  FGA  FG_PCT  \
# 0  By Period            1  74  29  45  0.392  11.0  2.7  5.7   0.476
# 1  By Period            2  74  29  45  0.392   6.3  1.5  3.7   0.421
# 2  By Period            3  71  29  42  0.408  10.9  2.6  6.3   0.422
# 3  By Period            4  64  27  37  0.422   7.2  1.4  3.6   0.391
# 4  By Period            5   3   1   2  0.333   5.0  1.7  4.0   0.417
# 5  By Period            6   1   0   1  0.000   4.8  3.0  5.0   0.600
#
#      ...     BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0    ...            2          4        4         2         2
# 1    ...            5          3        5         4         4
# 2    ...            3          2        2         1         1
# 3    ...            4          1        3         3         5
# 4    ...            1          5        6         5         6
# 5    ...            6          6        1         6         3
#
# ...

# %%
player.PlayerInGameSplits('2546').by_period().columns
# Out:
# Index(['GROUP_SET', 'GROUP_VALUE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD',
#        'PTS', 'PLUS_MINUS', 'DD2', 'TD3', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'DD2_RANK', 'TD3_RANK', 'CFID',
#        'CFPARAMS'],
#       dtype='object')

# %%
cur_df = player.PlayerInGameSplits('2546').by_period()

# %%
cur_df.ix[0]['FGA']
# Out:
# 5.7000000000000002

# %%
import tqdm

# %%
fourth_quarter_FGA = []
fourth_quarter_FGP = []
first_quarter_FGA = []
first_quarter_FGP = []
for p_id in tqdm.tqdm(main_df['PERSON_ID']):
    cur_df = player.PlayerInGameSplits(p_id).by_period()
    if len(cur_df) >= 4:
        first_quarter_FGA.append(cur_df.ix[0]['FGA'])
        first_quarter_FGP.append(cur_df.ix[0]['FG_PCT'])
        fourth_quarter_FGA.append(cur_df.ix[3]['FGA'])
        fourth_quarter_FGP.append(cur_df.ix[3]['FG_PCT'])
    else:
        first_quarter_FGA.append(None)
        first_quarter_FGP.append(None)
        fourth_quarter_FGA.append(None)
        fourth_quarter_FGP.append(None)
# Out:
# ...
# 100%|██████████| 491/491 [31:02<00:00,  3.09s/it]

# %%
main_df['Q1_FGA'] = first_quarter_FGA
main_df['Q4_FGA'] = fourth_quarter_FGA
main_df['Q1_FG_PCT'] = first_quarter_FGP
main_df['Q4_FG_PCT'] = fourth_quarter_FGP
# Out:
# /Users/andrewzhuang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/andrewzhuang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/andrewzhuang/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
main_df
# Out:
#      PERSON_ID     DISPLAY_FIRST_LAST  Q1_FGA  Q4_FGA  Q1_FG_PCT  Q4_FG_PCT
# 0       203518           Alex Abrines     1.7     1.8      0.440      0.375
# 1       203112             Quincy Acy     1.8     1.5      0.395      0.479
# 2       203500           Steven Adams     3.2     1.1      0.569      0.556
# 3       201167          Arron Afflalo     2.4     1.4      0.441      0.379
# 4       201582          Alexis Ajinca     1.8     1.1      0.453      0.464
# 5       202332           Cole Aldrich     0.5     0.6      0.462      0.381
# 6       200746      LaMarcus Aldridge     4.6     3.2      0.465      0.454
# 7       202730            Lavoy Allen     1.1     0.6      0.491      0.516
# 8         2754             Tony Allen     2.3     1.7      0.454      0.475
# 9       202329        Al-Farouq Aminu     1.7     1.9      0.443      0.369
# 10        2365         Chris Andersen     0.6     1.5      0.000      0.375
# ...

# %%
Tony_Allen = player.PlayerShotTracking('2754')

# %%
Tony_Allen.closest_defender_shooting()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  \
# 0       2754            Allen, Tony           1  71  69
# 1       2754            Allen, Tony           2  71  66
# 2       2754            Allen, Tony           3  71  49
# 3       2754            Allen, Tony           4  71  43
#
#     CLOSE_DEF_DIST_RANGE  FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  \
# 0  0-2 Feet - Very Tight          0.358  1.27  3.00   0.423    0.423
# 1       2-4 Feet - Tight          0.398  1.75  3.34   0.523    0.523
# 2        4-6 Feet - Open          0.129  0.45  1.08   0.416    0.442
# 3    6+ Feet - Wide Open          0.114  0.39  0.96   0.412    0.493
#
#    FG2A_FREQUENCY  FG2M  FG2A  FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0           0.356  1.27  2.99    0.425           0.002  0.00  0.01    0.000
# 1           0.392  1.75  3.28    0.532           0.007  0.00  0.06    0.000
# 2           0.101  0.39  0.85    0.467           0.029  0.06  0.24    0.235
# ...

# %%
Tony_Allen.closest_defender_shooting_long()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  \
# 0       2754            Allen, Tony           1  71   3
# 1       2754            Allen, Tony           2  71  12
# 2       2754            Allen, Tony           3  71  29
# 3       2754            Allen, Tony           4  71  36
#
#     CLOSE_DEF_DIST_RANGE  FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  \
# 0  0-2 Feet - Very Tight          0.005  0.00  0.04   0.000    0.000
# 1       2-4 Feet - Tight          0.020  0.01  0.17   0.083    0.083
# 2        4-6 Feet - Open          0.061  0.13  0.51   0.250    0.306
# 3    6+ Feet - Wide Open          0.094  0.27  0.79   0.339    0.438
#
#    FG2A_FREQUENCY  FG2M  FG2A  FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0           0.003  0.00  0.03    0.000           0.002  0.00  0.01    0.000
# 1           0.013  0.01  0.11    0.125           0.007  0.00  0.06    0.000
# 2           0.032  0.07  0.27    0.263           0.029  0.06  0.24    0.235
# ...

# %%
Tony_Allen.dribble_shooting()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G DRIBBLE_RANGE  \
# 0       2754            Allen, Tony           1  71  69    0 Dribbles
# 1       2754            Allen, Tony           2  71  50     1 Dribble
# 2       2754            Allen, Tony           3  71  35    2 Dribbles
# 3       2754            Allen, Tony           4  71  48  3-6 Dribbles
# 4       2754            Allen, Tony           5  71  30   7+ Dribbles
#
#    FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.553  2.13  4.63   0.459    0.482           0.467  1.92  3.92
# 1          0.170  0.75  1.42   0.525    0.525           0.170  0.75  1.42
# 2          0.079  0.28  0.66   0.426    0.426           0.079  0.28  0.66
# 3          0.129  0.45  1.08   0.416    0.416           0.124  0.45  1.04
# 4          0.069  0.25  0.58   0.439    0.439           0.069  0.25  0.58
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.489           0.086  0.21  0.72    0.294
# ...

# %%
Tony_Allen.shot_clock_shooting()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  SHOT_CLOCK_RANGE  \
# 0       2754            Allen, Tony           1  71  44             24-22
# 1       2754            Allen, Tony           2  71  53  22-18 Very Early
# 2       2754            Allen, Tony           3  71  49       18-15 Early
# 3       2754            Allen, Tony           4  71  70      15-7 Average
# 4       2754            Allen, Tony           5  71  29          7-4 Late
# 5       2754            Allen, Tony           6  71  31     4-0 Very Late
# 6       2754            Allen, Tony           7  71   4     ShotClock Off
#
#    FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.123  0.58  1.03   0.562    0.562           0.121  0.58  1.01
# 1          0.158  0.79  1.32   0.596    0.596           0.155  0.79  1.30
# 2          0.129  0.48  1.08   0.442    0.442           0.126  0.48  1.06
# 3          0.449  1.51  3.76   0.401    0.425           0.390  1.32  3.27
# ...

# %%
Tony_Allen.touch_time_shooting()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G   TOUCH_TIME_RANGE  \
# 0       2754            Allen, Tony           1  71  70  Touch < 2 Seconds
# 1       2754            Allen, Tony           2  71  61  Touch 2-6 Seconds
# 2       2754            Allen, Tony           3  71  34   Touch 6+ Seconds
#
#    FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.666  2.65  5.58   0.475    0.494           0.580  2.44  4.86
# 1          0.252  0.93  2.11   0.440    0.440           0.249  0.93  2.08
# 2          0.082  0.28  0.69   0.408    0.408           0.081  0.28  0.68
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.501           0.086  0.21  0.72    0.294
# 1    0.446           0.003  0.00  0.03    0.000
# 2    0.417           0.002  0.00  0.01    0.000

# %%
Tony_Allen.general_shooting()
# Out:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G        SHOT_TYPE  \
# 0       2754            Allen, Tony           1  71  51  Catch and Shoot
# 1       2754            Allen, Tony           2  71  20         Pull Ups
# 2       2754            Allen, Tony           3  71  71  Less than 10 ft
# 3       2754            Allen, Tony           4  71   1            Other
#
#    FGA_FREQUENCY   FGM   FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.143  0.38  1.20   0.318    0.406           0.057  0.17  0.48
# 1          0.035  0.03  0.30   0.095    0.095           0.030  0.03  0.25
# 2          0.820  3.45  6.87   0.502    0.502           0.820  3.45  6.87
# 3          0.002  0.00  0.01   0.000    0.000           0.002  0.00  0.01
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.353           0.086  0.21  0.72    0.294
# 1    0.111           0.005  0.00  0.04    0.000
# 2    0.502           0.000  0.00  0.00      NaN
# ...

# %%
CD_2ft_FGA = []
CD_4ft_FGA = []
CD_6ft_FGA = []
CD_open_FGA = []
CD_2ft_FG_PCT = []
CD_4ft_FG_PCT = []
CD_6ft_FG_PCT = []
CD_open_FG_PCT = []

CD_long_2ft_FGA = []
CD_long_4ft_FGA = []
CD_long_6ft_FGA = []
CD_long_open_FGA = []
CD_long_2ft_FG_PCT = []
CD_long_4ft_FG_PCT = []
CD_long_6ft_FG_PCT = []
CD_long_open_FG_PCT = []

Drib_0_FGA = []
Drib_1_FGA = []
Drib_2_FGA = []
Drib_3_FGA = []
Drib_7_FGA = []
Drib_0_FG_PCT = []
Drib_1_FG_PCT = []
Drib_2_FG_PCT = []
Drib_3_FG_PCT = []
Drib_7_FG_PCT = []

SC_24_FGA = []
SC_22_FGA = []
SC_18_FGA = []
SC_15_FGA = []
SC_7_FGA = []
SC_4_FGA = []
SC_0_FGA = []
SC_24_FG_PCT = []
SC_22_FG_PCT = []
SC_18_FG_PCT = []
SC_15_FG_PCT = []
SC_7_FG_PCT = []
SC_4_FG_PCT = []
SC_0_FG_PCT = []

TT_2_FGA = []
TT_6_FGA = []
TT_long_FGA = []
TT_2_FG_PCT = []
TT_6_FG_PCT = []
TT_long_FG_PCT = []

ST_CS_FGA = []
ST_PU_FGA = []
ST_LT10_FGA = []
ST_Other_FGA = []
ST_CS_FG_PCT = []
ST_PU_FG_PCT = []
ST_LT10_FG_PCT = []
ST_Other_FG_PCT = []

# %%
for p_id in tqdm.tqdm(main_df['PERSON_ID']):
    cur_player = player.PlayerShotTracking(p_id)
    if len(cur_player.closest_defender_shooting()) >= 4:
        CD_2ft_FGA.append(cur_player.closest_defender_shooting().ix[0]['FGA'])
        CD_4ft_FGA.append(cur_player.closest_defender_shooting().ix[1]['FGA'])
        CD_6ft_FGA.append(cur_player.closest_defender_shooting().ix[2]['FGA'])
        CD_open_FGA.append(cur_player.closest_defender_shooting().ix[3]['FGA'])
        CD_2ft_FG_PCT.append(cur_player.closest_defender_shooting().ix[0]['FG_PCT'])
        CD_4ft_FG_PCT.append(cur_player.closest_defender_shooting().ix[1]['FG_PCT'])
        CD_6ft_FG_PCT.append(cur_player.closest_defender_shooting().ix[2]['FG_PCT'])
        CD_open_FG_PCT.append(cur_player.closest_defender_shooting().ix[3]['FG_PCT'])
    else:
        CD_2ft_FGA.append(None)
        CD_4ft_FGA.append(None)
        CD_6ft_FGA.append(None)
        CD_open_FGA.append(None)
        CD_2ft_FG_PCT.append(None)
        CD_4ft_FG_PCT.append(None)
        CD_6ft_FG_PCT.append(None)
        CD_open_FG_PCT.append(None)

main_df['CD_2ft_FGA'] = CD_2ft_FGA
main_df['CD_4ft_FGA'] = CD_4ft_FGA
main_df['CD_6ft_FGA'] = CD_6ft_FGA
main_df['CD_open_FGA'] = CD_open_FGA
main_df['CD_2ft_FG_PCT'] = CD_2ft_FG_PCT
main_df['CD_4ft_FG_PCT'] = CD_4ft_FG_PCT
main_df['CD_6ft_FG_PCT'] = CD_6ft_FG_PCT
main_df['CD_open_FG_PCT'] = CD_open_FG_PCT
# Out:
# 100%|██████████| 491/491 [03:58<00:00,  2.04it/s]

# %%
main_df.to_csv('main_df.csv')

# %%
TA2.assisted_shots()
# Out:
#        GROUP_SET GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  EFG_PCT  \
# 0  Assisted Shot    Assisted  158  158     1.0    15    15      1.0    1.047
# 1  Assisted Shot  Unassisted  116  116     1.0     0     0      0.0    1.000
#
#    BLKA     ...      EFG_PCT_RANK  BLKA_RANK  PCT_AST_2PM_RANK  \
# 0     0     ...                 1          1                 1
# 1     0     ...                 2          1                 2
#
#    PCT_UAST_2PM_RANK  PCT_AST_3PM_RANK  PCT_UAST_3PM_RANK  PCT_AST_FGM_RANK  \
# 0                  2                 1                  1                 1
# 1                  1                 2                  1                 2
#
#    PCT_UAST_FGM_RANK  CFID    CFPARAMS
# 0                  2    46    Assisted
# 1                  1    46  Unassisted
#
# [2 rows x 32 columns]

# %%
TA2.shot_5ft()
# Out:
#              GROUP_SET      GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  Shot Distance (5ft)  Less Than 5 ft.  229  441   0.519     0     0
# 1  Shot Distance (5ft)          5-9 ft.   14   46   0.304     0     0
# 2  Shot Distance (5ft)        10-14 ft.    5   16   0.313     0     0
# 3  Shot Distance (5ft)        15-19 ft.    3   17   0.176     0     0
# 4  Shot Distance (5ft)        20-24 ft.   20   67   0.299    12    46
# 5  Shot Distance (5ft)        25-29 ft.    3    8   0.375     3     8
# 6  Shot Distance (5ft)        30-34 ft.    0    0   0.000     0     0
# 7  Shot Distance (5ft)        35-39 ft.    0    0   0.000     0     0
# 8  Shot Distance (5ft)          40+ ft.    0    0   0.000     0     0
#
#    FG3_PCT  EFG_PCT  BLKA       ...         EFG_PCT_RANK  BLKA_RANK  \
# 0    0.000    0.519    65       ...                    2          9
# 1    0.000    0.304     6       ...                    5          8
# ...

# %%
TA2.shot_8ft()
# Out:
#              GROUP_SET      GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  Shot Distance (8ft)  Less Than 8 ft.  242  481   0.503     0     0
# 1  Shot Distance (8ft)         8-16 ft.    7   24   0.292     0     0
# 2  Shot Distance (8ft)        16-24 ft.   10   36   0.278     0     0
# 3  Shot Distance (8ft)          24+ ft.   15   54   0.278    15    54
# 4  Shot Distance (8ft)  Back Court Shot    0    0   0.000     0     0
#
#    FG3_PCT  EFG_PCT  BLKA       ...         EFG_PCT_RANK  BLKA_RANK  \
# 0    0.000    0.503    71       ...                    1          5
# 1    0.000    0.292     1       ...                    3          4
# 2    0.000    0.278     0       ...                    4          1
# 3    0.278    0.417     0       ...                    2          1
# 4    0.000    0.000     0       ...                    5          1
#
#    PCT_AST_2PM_RANK  PCT_UAST_2PM_RANK  PCT_AST_3PM_RANK  PCT_UAST_3PM_RANK  \
# ...

# %%
TA2.shot_areas()
# Out:
#    GROUP_SET            GROUP_VALUE  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0  Shot Area        Restricted Area  222  422   0.526     0     0    0.000
# 1  Shot Area  In The Paint (Non-RA)   25   75   0.333     0     0    0.000
# 2  Shot Area              Mid-Range   12   44   0.273     0     0    0.000
# 3  Shot Area          Left Corner 3    5   12   0.417     5    12    0.417
# 4  Shot Area         Right Corner 3    7   26   0.269     7    26    0.269
# 5  Shot Area      Above the Break 3    3   16   0.188     3    16    0.188
# 6  Shot Area              Backcourt    0    0   0.000     0     0    0.000
#
#    EFG_PCT  BLKA          ...            EFG_PCT_RANK  BLKA_RANK  \
# 0    0.526    62          ...                       2          7
# 1    0.333    10          ...                       4          6
# 2    0.273     0          ...                       6          1
# 3    0.625     0          ...                       1          1
# ...

# %%
TA2.shot_types_detail()
# Out:
#            GROUP_SET                         GROUP_VALUE  FGM  FGA  FG_PCT  \
# 0   Shot Type Detail                 Alley Oop Dunk Shot    0    0   0.000
# 1   Shot Type Detail                Alley Oop Layup shot    0    0   0.000
# 2   Shot Type Detail                   Cutting Dunk Shot    6    6   1.000
# 3   Shot Type Detail      Cutting Finger Roll Layup Shot    2    2   1.000
# 4   Shot Type Detail                  Cutting Layup Shot   33   58   0.569
# 5   Shot Type Detail              Driving Bank Hook Shot    0    0   0.000
# 6   Shot Type Detail                   Driving Bank shot    0    1   0.000
# 7   Shot Type Detail                   Driving Dunk Shot    0    0   0.000
# 8   Shot Type Detail      Driving Finger Roll Layup Shot    4    6   0.667
# 9   Shot Type Detail     Driving Floating Bank Jump Shot    0    1   0.000
# 10  Shot Type Detail          Driving Floating Jump Shot    3    3   1.000
# ...

# %%
print(__doc__)

from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
# Out:
# Automatically created module for IPython interactive environment

# %%
main_df
# Out:
#      PERSON_ID     DISPLAY_FIRST_LAST  Q1_FGA  Q4_FGA  Q1_FG_PCT  Q4_FG_PCT  \
# 0       203518           Alex Abrines     1.7     1.8      0.440      0.375
# 1       203112             Quincy Acy     1.8     1.5      0.395      0.479
# 2       203500           Steven Adams     3.2     1.1      0.569      0.556
# 3       201167          Arron Afflalo     2.4     1.4      0.441      0.379
# 4       201582          Alexis Ajinca     1.8     1.1      0.453      0.464
# 5       202332           Cole Aldrich     0.5     0.6      0.462      0.381
# 6       200746      LaMarcus Aldridge     4.6     3.2      0.465      0.454
# 7       202730            Lavoy Allen     1.1     0.6      0.491      0.516
# 8         2754             Tony Allen     2.3     1.7      0.454      0.475
# 9       202329        Al-Farouq Aminu     1.7     1.9      0.443      0.369
# 10        2365         Chris Andersen     0.6     1.5      0.000      0.375
# ...

# %%
main_df_red = main_df.copy(deep = True)

# %%
del main_df_red['DISPLAY_FIRST_LAST']

# %%
main_df_red = main_df_red.dropna()

# %%
reduced_data = PCA(n_components=2).fit_transform(main_df_red)

# %%
kmeans = KMeans(init='k-means++', n_clusters=10, n_init=10)
kmeans.fit(reduced_data)

# Step size of the mesh. Decrease to increase the quality of the VQ.
h = .02     # point in the mesh [x_min, x_max]x[y_min, y_max].

# Plot the decision boundary. For that, we will assign a color to each
x_min, x_max = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
y_min, y_max = reduced_data[:, 1].min() - 1, reduced_data[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Obtain labels for each point in mesh. Use last trained model.
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Paired,
           aspect='auto', origin='lower')

plt.plot(reduced_data[:, 0], reduced_data[:, 1], 'k.', markersize=2)
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', s=169, linewidths=3,
            color='w', zorder=10)
plt.title('K-means clustering on the digits dataset (PCA-reduced data)\n'
          'Centroids are marked with white cross')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.show()
