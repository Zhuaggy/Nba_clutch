# %% [markdown]
# ## SC_FG_PCT vs SC_FG3_PCT

# %%
a.plot(y = 'SC_FG_PCT_DIFF', x = 'SC_FG3_PCT_DIFF', kind = 'scatter')

# %% [markdown]
# The above figure shows the relationship between Field goal percentage and 3 point percentage under the constraint of low shot clock time
